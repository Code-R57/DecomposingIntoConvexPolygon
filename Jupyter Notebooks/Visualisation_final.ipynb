# %%
import numpy as np
import pandas as pd
import re

# %%
pip install shapely
# Out:
# Requirement already satisfied: shapely in c:\users\dhruv\appdata\local\programs\python\python310\lib\site-packages (2.0.1)
# Requirement already satisfied: numpy>=1.14 in c:\users\dhruv\appdata\local\programs\python\python310\lib\site-packages (from shapely) (1.22.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: C:\Users\dhruv\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Polygon
# %matplotlib inline

# %%
filename = "./countries/file_verma.txt"
file = open(filename, 'r')

# %%
lines = file.readlines()
# print(file)
lines = [item.strip() for item in lines]
print(lines)
# Out:
# ['8', '28 -292', '54 -247', '198 -236', '129 -211', '237 -66', '382 -178', '350 -327', '158 -347']

# %%
number_of_points  = lines[0]
lines.pop(0)
print(lines)
# Out:
# ['28 -292', '54 -247', '198 -236', '129 -211', '237 -66', '382 -178', '350 -327', '158 -347']

# %%
lines
# Out:
# ['28 -292',
#  '54 -247',
#  '198 -236',
#  '129 -211',
#  '237 -66',
#  '382 -178',
#  '350 -327',
#  '158 -347']

# %%
x = [eval(item.split(" ")[0]) for item in lines]
y = [eval(item.split(" ")[1]) for item in lines]

print(x)
print(y)
# Out:
# [28, 54, 198, 129, 237, 382, 350, 158]
# [-292, -247, -236, -211, -66, -178, -327, -347]

# %%
polygon = Polygon(zip(x, y))
# plot the polygon using matplotlib
fig, ax = plt.subplots(figsize=(16,16))
ax.plot(*polygon.exterior.xy)
ax.set_aspect('equal')
plt.show()


# Set the x and y axis labels
